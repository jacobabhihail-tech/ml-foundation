# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
data = load_breast_cancer()
X = data.data
y = data.target

print("Data loaded. Shape:", X.shape)
# Out:
# Data loaded. Shape: (569, 30)

# %%
model = RandomForestClassifier(
    n_estimators=50,
    random_state=42
)

model.fit(X, y)

print("Model trained.")
# Out:
# Model trained.

# %%
joblib.dump(model, "rf_model.pkl")

print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
loaded_model = joblib.load("rf_model.pkl")

print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %%
original_preds = model.predict(X[:3])
loaded_preds = loaded_model.predict(X[:3])

print("Original Model Predictions:", original_preds)
print("Loaded Model Predictions:  ", loaded_preds)
# Out:
# Original Model Predictions: [0 0 0]
# Loaded Model Predictions:   [0 0 0]
