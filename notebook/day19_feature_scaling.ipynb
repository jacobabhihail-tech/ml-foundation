# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Sample feature data
X = np.array([[2, 30000],
              [5, 50000],
              [10, 100000]])


print("Original Data:\n", X)
# Out:
# Original Data:
#  [[     2  30000]
#  [     5  50000]
#  [    10 100000]]

# %%
# standard scaling

standard_scaler = StandardScaler()
x_standard = standard_scaler.fit_transform(X)

print("\n Standard Scaled Data: ", x_standard)
# Out:
#  Standard Scaled Data:  [[-1.1111678  -1.01904933]
#  [-0.20203051 -0.33968311]
#  [ 1.31319831  1.35873244]]

# %%
# min-max scaling
minmax_scaler = MinMaxScaler()
x_minmax = minmax_scaler.fit_transform(X)

print("\nMin-Max Scaled Data: ", x_minmax)
# Out:
# Min-Max Scaled Data:  [[0.         0.        ]
#  [0.375      0.28571429]
#  [1.         1.        ]]
